# %%
import urllib
url = 'https://opendata-ajuntament.barcelona.cat/data/api/action/datastore_search?resource_id=709aa0d3-15ef-472a-a303-976329af44a7&limit=5&q=title:jones'
fileobj = urllib.opendataurlopen(url)
fileobj.read()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-111-55970f5ee3f3> in <cell line: 3>()
#       1 import urllib
#       2 url = 'https://opendata-ajuntament.barcelona.cat/data/api/action/datastore_search?resource_id=709aa0d3-15ef-472a-a303-976329af44a7&limit=5&q=title:jones'
# ----> 3 fileobj = urllib.urlopen(url)
#       4 fileobj.read()
#
# AttributeError: module 'urllib' has no attribute 'urlopen'

# %%
import pandas as pd

# %%
api_key_news = '65a17eb5648147268a7dbb97d155f528'

# %%
# !pip install newsapi-python
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from newsapi import NewsApiClient

# Init
newsapi = NewsApiClient(api_key=api_key_news)

# %%
newsapi.get_sources(category='general',
                    language='es',
                    country='es')
# Out:
# {'status': 'ok',
#  'sources': [{'id': 'el-mundo',
#    'name': 'El Mundo',
#    'description': 'Noticias, actualidad, álbumes, debates, sociedad, servicios, entretenimiento y última hora en España y el mundo.',
#    'url': 'http://www.elmundo.es',
#    'category': 'general',
#    'language': 'es',
#    'country': 'es'}]}

# %%
news = newsapi.get_everything(q = ('accidente vial' or 'accidente' or 'trafico' or 'barcelona'),
                              language = 'es',
                              sort_by = 'publishedAt')

# %%
news
# Out:
# {'status': 'ok',
#  'totalResults': 145,
#  'articles': [{'source': {'id': None, 'name': 'Eluniversal.com.co'},
#    'author': '',
#    'title': '¡Qué tragedia! Niña de 3 años murió al ser golpeada por un carro y una moto',
#    'description': 'La tragedia y el dolor envuelven con su manto a una familia cartagenera. Una niña, de apenas 3 años, murió en un accidente de tránsito que ocurrió en el barrio Nelson Mandela, sector El Bombeo.',
#    'url': 'https://www.eluniversal.com.co/sucesos/que-tragedia-nina-de-3-anos-murio-al-ser-golpeada-por-un-carro-y-una-moto-HA8266485',
#    'urlToImage': 'https://www.eluniversal.com.co/binrepository/1029x686/60c1/800d686/none/13704/UPFF/medicina-legal-datt-upj_7770460_20230508120624.jpg',
#    'publishedAt': '2023-05-08T17:09:02Z',
# ...

# %%
df_articles = pd.DataFrame.from_dict(news).articles

# %%
df_articles
# Out:
# 0     {'source': {'id': None, 'name': 'Eluniversal.c...
# 1     {'source': {'id': None, 'name': 'Elconfidencia...
# 2     {'source': {'id': None, 'name': 'El Financiero...
# 3     {'source': {'id': 'la-nacion', 'name': 'La Nac...
# 4     {'source': {'id': None, 'name': 'Www.abc.es'},...
#                             ...
# 95    {'source': {'id': None, 'name': 'Lavozdegalici...
# 96    {'source': {'id': None, 'name': 'Milenio'}, 'a...
# 97    {'source': {'id': None, 'name': 'Europapress.e...
# 98    {'source': {'id': None, 'name': 'El Financiero...
# 99    {'source': {'id': 'la-nacion', 'name': 'La Nac...
# Name: articles, Length: 100, dtype: object

# %%
df = pd.json_normalize(df_articles)

# %%
df
# Out:
#                            author  \
# 0
# 1                       Comunicae
# 2   Verónica Bacaz / Corresponsal
# 3                            None
# 4                           (abc)
# ..                            ...
# 95                         La Voz
# 96  Milenio Digital,Ramón Ramírez
# 97                           None
# 98                      Redacción
# 99                      LA NACION
#
#                                                 title  \
# 0   ¡Qué tragedia! Niña de 3 años murió al ser gol...
# 1   PF Led ONE, la baliza v16 conectada más vendid...
# 2   Marchan campesinos de Morelos a CDMX: ¿Cuáles ...
# 3   Panamericana: murió al destrozar su auto contr...
# 4   El paso elevado de Atocha que un taxista casti...
# ..                                                ...
# 95  Un coche arrolla a dos caballos en un atropell...
# 96  En regreso a clases, colapsa la México-Pachuca...
# 97  La DGT lanza una campaña preventiva para evita...
# ...
